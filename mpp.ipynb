# %% [markdown]
# <a href="https://colab.research.google.com/github/perjmi/multiperiod/blob/main/mpp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import requests
import io
import cvxpy as cp
import numpy as np

link='https://www.afkastforventninger.dk/media/1508/afkastforventninger-2-halvaar-2023.xlsx'
storage_options = {'User-Agent': 'Mozilla/5.0'}
def getreturns(sheet_name=0):
  f=pd.read_excel(link,storage_options=storage_options,sheet_name=sheet_name)
  f=f.iloc[6:16]
  asset_names=f['Unnamed: 2']
  asset_returns=f['Unnamed: 4']
  r=pd.DataFrame({'asset':asset_names,'return':asset_returns})
  r.set_index('asset',inplace=True)
  return r

def getcor():
  f=pd.read_excel(link,storage_options=storage_options,sheet_name=3)
  std=f.iloc[6:16][['Unnamed: 2','Unnamed: 4']]
  std.columns=['asset',"std"]
  std.set_index('asset',inplace=True)
  cor=f.iloc[19:30][f.columns[13:23]]
  cor.columns=std.index
  cor['asset']=std.index
  cor.set_index('asset',inplace=True)
  for i in range(cor.shape[0]):
    for j in range(i):
      cor.iloc[i][j]=cor.iloc[j][i]
  #f=f.iloc[6:16]
  return std,cor

# %%
returns1_5=getreturns(0)
returns6_10=getreturns(1)
std,cor=getcor()

# %%
returns1_5.transpose() @ (cor @ returns1_5)
# Out:
#           return
# return  0.175711

# %%
import torch

w=torch.variable(10)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-145-32d2efb49185> in <cell line: 3>()
#       1 import torch
#       2
# ----> 3 w=torch.variable(10)
#
# AttributeError: module 'torch' has no attribute 'variable'

# %%
x = cp.Variable(returns1_5.shape[0])
objective = cp.Minimize(cp.transpose(x) @ cor @ x )
constraints = [0 <= x, x <= 1]
constraints = [0<=x, x<=1, cp.sum(x)==1]
prob = cp.Problem(objective, constraints)
result = prob.solve()
# The optimal value for x is stored in `x.value`.
print(x.value)
print(x.value.sum())
# The optimal Lagrange multiplier for a constraint is stored in
# `constraint.dual_value`.
print(constraints[0].dual_value)
# Out:
# ---------------------------------------------------------------------------
# DCPError                                  Traceback (most recent call last)
# <ipython-input-144-18251737be5f> in <cell line: 6>()
#       4 constraints = [0<=x, x<=1, cp.sum(x)==1]
#       5 prob = cp.Problem(objective, constraints)
# ----> 6 result = prob.solve()
#       7 # The optimal value for x is stored in `x.value`.
#       8 print(x.value)
#
# /usr/local/lib/python3.10/dist-packages/cvxpy/problems/problem.py in solve(self, *args, **kwargs)
#     491         else:
#     492             solve_func = Problem._solve
# --> 493         return solve_func(self, *args, **kwargs)
#     494
#     495     @classmethod
#
# /usr/local/lib/python3.10/dist-packages/cvxpy/problems/problem.py in _solve(self, solver, warm_start, verbose, gp, qcp, requires_grad, enforce_dpp, ignore_dpp, canon_backend, **kwargs)
#    1052                 return self.value
#    1053
# ...

# %%
a,b=getcor()

# %%
a
# Out:
#                                       std
# asset
# Stats- og realkreditobligationer    0.039
# Investment-grade obligationer       0.052
# High-yield obligationer             0.105
# Emerging markets statsobligationer  0.085
# Globale aktier (developed markets)  0.155
# Emerging markets aktier             0.199
# Private equity                      0.216
# Infrastruktur                       0.129
# Ejendomme                           0.089
# Hedgefonde                          0.087

# %%
b
# Out:
# asset                               Stats- og realkreditobligationer  \
# asset
# Stats- og realkreditobligationer                                 1.0
# Investment-grade obligationer                                    0.6
# High-yield obligationer                                          0.1
# Emerging markets statsobligationer                               0.3
# Globale aktier (developed markets)                              -0.1
# Emerging markets aktier                                         -0.1
# Private equity                                                  -0.2
# Infrastruktur                                                   -0.1
# Ejendomme                                                       -0.1
# Hedgefonde                                                      -0.1
#
# asset                               Investment-grade obligationer  \
# asset
# Stats- og realkreditobligationer                              0.6
# ...

# %%
b.iloc[1][2]
# Out:
# 0.6

# %%
# Problem data.
m = 30
n = 20
np.random.seed(1)
A = np.random.randn(m, n)
b = np.random.randn(m)

# Construct the problem.
x = cp.Variable(n)
objective = cp.Minimize(cp.sum_squares(A @ x - b))
constraints = [0 <= x, x <= 1]
constraints = [0<=x, x<=1, cp.sum(x)==1]
prob = cp.Problem(objective, constraints)

# The optimal objective value is returned by `prob.solve()`.
result = prob.solve()
# The optimal value for x is stored in `x.value`.
print(x.value)
print(x.value.sum())
# The optimal Lagrange multiplier for a constraint is stored in
# `constraint.dual_value`.
print(constraints[0].dual_value)
# Out:
# [-6.39782540e-18 -8.43097741e-18  4.20602023e-19 -1.93768029e-18
#  -5.70965317e-18  1.25673263e-01 -5.76474369e-18 -7.31813674e-19
#   1.66909960e-01  5.07152051e-01 -4.41869461e-18 -3.20230006e-18
#  -4.27969604e-18  2.00264725e-01 -3.40431865e-18 -1.16929383e-17
#  -6.05404354e-18 -8.09357284e-18 -6.28924454e-18 -1.27705490e-17]
# 1.0000000000000002
# [ 4.74927098  0.84200494  2.9662478   2.42832859 14.67384044  0.
#   2.72521392  4.86293773  0.          0.         10.0381944   1.69313676
#   8.62353598  0.          6.15221195  6.78032315  3.11707084 12.55790821
#   5.27366889 11.70295745]
